# %%
import numpy as np
import pandas as pd

# %%
#loading dataset
urldata = pd.read_csv("F:\\urldata.csv",encoding = "ISO-8859-1")
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_18712\3574544607.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   urldata = pd.read_csv("F:\\urldata.csv",encoding = "ISO-8859-1")

# %%
urldata
# Out:
#                                                   domain   ranking  mld_res  \
# 0      nobell.it/70ffb52d079109dca5664cce6f317373782/...  10000000        1
# 1      www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...  10000000        0
# 2      serviciosbys.com/paypal.cgi.bin.get-into.herf....  10000000        0
# 3      mail.printakid.com/www.online.americanexpress....  10000000        0
# 4      thewhiskeydregs.com/wp-content/themes/widescre...  10000000        0
# ...                                                  ...       ...      ...
# 95908            xbox360.ign.com/objects/850/850402.html       339        1
# 95909       games.teamxbox.com/xbox-360/1860/Dead-Space/     63029        1
# 95910         www.gamespot.com/xbox360/action/deadspace/       753        1
# 95911      en.wikipedia.org/wiki/Dead_Space_(video_game)         6        1
# 95912          www.angelfire.com/goth/devilmaycrytonite/      2547        1
#
#        mld.ps_res  card_rem  ratio_Rrem  ratio_Arem  jaccard_RR  jaccard_RA  \
# 0               0        18  107.611111  107.277778    0.000000    0.000000
# 1               0        11  150.636364  152.272727    0.000000    0.000000
# 2               0        14   73.500000   72.642857    0.000000    0.000000
# 3               0         6  562.000000  590.666667    0.000000    0.000000
# 4               0         8   29.000000   24.125000    0.000000    0.000000
# ...           ...       ...         ...         ...         ...         ...
# 95908           1         2  142.500000  141.000000    0.009009    0.009091
# 95909           0         3  114.000000  128.333333    0.002899    0.002577
# 95910           1         3   91.000000  101.333333    0.000000    0.003106
# 95911           1         4  682.000000  744.250000    0.033075    0.029412
# 95912           1         5   32.400000   27.200000    0.022222    0.032680
#
#        jaccard_AR  jaccard_AA  jaccard_ARrd  jaccard_ARrem  label
# 0        0.000000    0.000000      0.800000       0.795729      1
# 1        0.000000    0.000000      0.000000       0.768577      1
# 2        0.000000    0.000000      0.000000       0.726582      1
# 3        0.000000    0.000000      0.000000       0.859640      1
# 4        0.000000    0.000000      0.000000       0.748971      1
# ...           ...         ...           ...            ...    ...
# 95908    0.006536    0.006601      0.450980       0.846906      0
# 95909    0.002907    0.002584      0.750000       0.714623      0
# 95910    0.000000    0.000000      0.111111       0.648571      0
# 95911    0.030250    0.029145      0.809735       0.840323      0
# 95912    0.017341    0.020408      0.636364       0.674157      0
#
# [95913 rows x 14 columns]

# %%
urldata.shape
# Out:
# (95913, 14)

# %%
#taking only required columns into a new Dataframe
urldata = urldata.filter(['domain','label'],axis=1)

# %%
urldata.head()
# Out:
#                                               domain  label
# 0  nobell.it/70ffb52d079109dca5664cce6f317373782/...      1
# 1  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...      1
# 2  serviciosbys.com/paypal.cgi.bin.get-into.herf....      1
# 3  mail.printakid.com/www.online.americanexpress....      1
# 4  thewhiskeydregs.com/wp-content/themes/widescre...      1

# %%
urldata.tail()
# Out:
#                                               domain  label
# 95908        xbox360.ign.com/objects/850/850402.html      0
# 95909   games.teamxbox.com/xbox-360/1860/Dead-Space/      0
# 95910     www.gamespot.com/xbox360/action/deadspace/      0
# 95911  en.wikipedia.org/wiki/Dead_Space_(video_game)      0
# 95912      www.angelfire.com/goth/devilmaycrytonite/      0

# %%
urldata.shape
